# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas26-web/meio-P.A/blob/main/aula_meio_p_a_(%C3%A1rea).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# cálculo de área

# entrada

lado_1 = 5
lado_2 = 4

nome = "Lucas Fernando"

# %%
# processamento

área = lado_1 * lado_2

# %%
# saída

print(f"Total da área:{área}")
# Out:
# Total da área:20

# %% [markdown]
# #aula de programação e algorítmo
# -cálculo da área
#
# #entrada
# -ler lado 1
# -ler lado 2
#
# #processamento
# área = lado1* lado2
#
# #saída
# imprimir área

# %%
# tipos numéricos
idade = 15 # int
altura = 1.70 #float
numero_complexo = 5 + 3 # complex

# tipo texto
esta_chovendo = False # boll
