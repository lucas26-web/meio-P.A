# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas26-web/meio-P.A/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# cria um programa que verifica se o número é par ou ímpar

# entrada

numero = int(input("Digite um número:"))

if numero % 2 == 0:
    print (f"O número {numero}, é um número par.")
else:
    print (f"O número {numero}, é um número ímpar")
# Out:
# Digite um número:6
# O número 6, é um número par.

# %%
# escrever um programa que o usuário digita o nome e as suas 04 notas refeente aos bimestres, calcula a média e mostra
#aprovado, rescuperação ou reprovado.

#nota maior ou igual a sete aprovado;
#nota maior ou igual 5 e menor 7 recuperação;
#nota menor 5 reprovado;

# entrada

nome = str (input("Digite seu nome: "))
nota1 = float (input("Digite sua nota do 1°  bimestre:  "))
nota2 = float (input("Digite sua nota do 2° bimestre:  "))
nota3 = float (input("Digite sua nota do 3°  bimestre:  "))
nota4 = float (input("Digite sua nota do 4°  bimestre:  "))


media = (nota1 + nota2 + nota3 + nota4) / 4


if media >= 7:
  print(f"{nome}, você foi aprovado com média {media}, parabéns!!")

elif media >= 5:
  print(f"{nome}, você está de recuperação, dá pra melhorar ;)")

else:
  print(f"{nome}, você foi reprovado.")
# Out:
# Digite seu nome: Lucas
# Digite sua nota do 1°  bimestre:  10
# Digite sua nota do 2° bimestre:  8
# Digite sua nota do 3°  bimestre:  4
# Digite sua nota do 4°  bimestre:  1
# Lucas, você está de recuperação, dá pra melhorar ;)

# %%
#escrever um programa que recebe os valores de 03 lados  e verificar se é um triângulo válido
# e classifica o tipo do triângulo

# verificar se o triângulo é válido;
 # * a soma das medidas de quaisquer dois lados deve ser sempre maior que a medida do terceiro lado.

 # classificar tipos de triângulos;

 # * equilatero - todos os lados iguais
 # * isoceles - os dois lados iguais
 # * escaleno - os tres lados sao diferentes

 # entrada
